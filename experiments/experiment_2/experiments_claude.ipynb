# %%
import os
import re
import json
import time
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")


import os
import re
import json
import time
from pathlib import Path

import pandas as pd
import requests
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")

DOMAINS = ["A", "B", "C", "D", "E"]

# ---- NEU: Output-Contract für EINEN Request mit A..E ----
OUTPUT_CONTRACT_DEFAULT = """
Return ONLY valid JSON (no markdown, no commentary).

Schema:
{
  "A": {"severity": <int or null>, "confidence": <float 0..1 or null>, "findings": <list of strings>},
  "B": {"severity": <int or null>, "confidence": <float 0..1 or null>, "findings": <list of strings>},
  "C": {"severity": <int or null>, "confidence": <float 0..1 or null>, "findings": <list of strings>},
  "D": {"severity": <int or null>, "confidence": <float 0..1 or null>, "findings": <list of strings>},
  "E": {"severity": <int or null>, "confidence": <float 0..1 or null>, "findings": <list of strings>}
}

Rules:
- findings must be short factual phrases grounded in the call text.
- if no findings are available for a domain, return [] for that domain.
- do NOT invent findings.
""".strip()

ABCDE_SCHEMA = {
    "type": "object",
    "properties": {
        "A": {"$ref": "#/$defs/domain"},
        "B": {"$ref": "#/$defs/domain"},
        "C": {"$ref": "#/$defs/domain"},
        "D": {"$ref": "#/$defs/domain"},
        "E": {"$ref": "#/$defs/domain"},
    },
    "required": ["A", "B", "C", "D", "E"],
    "additionalProperties": False,
    "$defs": {
        "domain": {
            "type": "object",
            "properties": {
                "severity": {"anyOf": [{"type": "integer"}, {"type": "null"}]},
                "confidence": {"anyOf": [{"type": "number"}, {"type": "null"}]},
                "findings": {"type": "array", "items": {"type": "string"}},
            },
            "required": ["severity", "confidence", "findings"],
            "additionalProperties": False,
        }
    },
}

def _safe_model_name(s: str) -> str:
    return re.sub(r"[^\w\.-]+", "-", s)

def _temp_tag(t: float) -> str:
    if float(t).is_integer():
        return f"t{int(t)}"
    return f"t{str(t).replace('.', '_')}"

def next_free_run_path(results_dir: Path, model: str, temperature: float) -> Path:
    results_dir.mkdir(parents=True, exist_ok=True)
    nums = []
    for p in results_dir.glob("run_*.csv"):
        m = re.search(r"run_(\d+)_", p.name)
        if m:
            nums.append(int(m.group(1)))
    n = (max(nums) + 1) if nums else 1
    return results_dir / f"run_{n}_{_safe_model_name(model)}_{_temp_tag(temperature)}.csv"


def _extract_text_from_anthropic_message(message_obj: dict) -> str:
    parts = []
    for c in message_obj.get("content", []) or []:
        if c.get("type") == "text" and "text" in c:
            parts.append(c["text"])
    return "\n".join(parts).strip()


# ---- NEU: Parser für EINEN Request pro Notruf (custom_id = Notruf_12) ----
def parse_anthropic_batch_results_jsonl_to_df(jsonl_text: str) -> pd.DataFrame:
    by_call = {}

    for line in jsonl_text.splitlines():
        if not line.strip():
            continue
        rec = json.loads(line)

        call_id = rec.get("custom_id")  # jetzt: "Notruf_12"
        if not call_id:
            continue

        by_call.setdefault(call_id, {"file": call_id})

        result = rec.get("result") or {}
        rtype = result.get("type")

        if rtype != "succeeded":
            for d in DOMAINS:
                by_call[call_id][f"severity_{d}"] = None
                by_call[call_id][f"confidence_{d}"] = None
                by_call[call_id][f"findings_{d}"] = json.dumps([], ensure_ascii=False)
                by_call[call_id][f"error_{d}"] = json.dumps(result, ensure_ascii=False)
            continue

        msg = result.get("message") or {}
        text = _extract_text_from_anthropic_message(msg)


        try:
            data = json.loads(text)  # Structured Output -> direkt valid JSON
        except Exception as e:
            for d in DOMAINS:
                by_call[call_id][f"severity_{d}"] = None
                by_call[call_id][f"confidence_{d}"] = None
                by_call[call_id][f"findings_{d}"] = json.dumps([], ensure_ascii=False)
                by_call[call_id][f"error_{d}"] = f"parse_error: {e}"
            continue
        m = re.search(r"\{.*\}", text, flags=re.S)
        

        try:
            data = json.loads(m.group(0))  # erwartet: {"A": {...}, ...}
        except Exception as e:
            for d in DOMAINS:
                by_call[call_id][f"severity_{d}"] = None
                by_call[call_id][f"confidence_{d}"] = None
                by_call[call_id][f"findings_{d}"] = json.dumps([], ensure_ascii=False)
                by_call[call_id][f"error_{d}"] = f"parse_error: {e}"
            continue

        for d in DOMAINS:
            block = data.get(d)
            if not isinstance(block, dict):
                by_call[call_id][f"severity_{d}"] = None
                by_call[call_id][f"confidence_{d}"] = None
                by_call[call_id][f"findings_{d}"] = json.dumps([], ensure_ascii=False)
                by_call[call_id][f"error_{d}"] = f"missing_or_invalid_block_{d}"
                continue

            sev = block.get("severity")
            conf = block.get("confidence")
            findings = block.get("findings", [])
            if findings is None:
                findings = []
            if not isinstance(findings, list):
                findings = [str(findings)]

            by_call[call_id][f"severity_{d}"] = sev
            by_call[call_id][f"confidence_{d}"] = conf
            by_call[call_id][f"findings_{d}"] = json.dumps(findings, ensure_ascii=False)
            by_call[call_id][f"error_{d}"] = None

    df = pd.DataFrame(list(by_call.values()))
    df["call_nr"] = df["file"].str.extract(r"(\d+)").astype("Int64")
    df = df.sort_values(["call_nr", "file"], na_position="last").reset_index(drop=True)

    cols = ["file", "call_nr"]
    for d in DOMAINS:
        cols += [f"severity_{d}", f"confidence_{d}", f"findings_{d}", f"error_{d}"]
    for c in cols:
        if c not in df.columns:
            df[c] = None
    return df[cols]


def run_abcde_batch_experiment_anthropic(
    model: str,
    temperature: float,
    *,
    calls_dir: Path,
    guidelines_dir: Path,      # enthält jetzt GENAU 1 Guideline-Datei
    results_dir: Path,
    max_tokens: int = 800,     # größer, weil A..E in einem Output
    poll_every_seconds: int = 30,
    output_contract: str = OUTPUT_CONTRACT_DEFAULT,
):
    """
    Claude Message Batches (Anthropic):
    - PRO NOTRUF genau 1 Request
    - guidelines_dir enthält GENAU 1 Master-Guideline
    - Output ist JSON mit A..E-Blöcken
    - Ergebnis wird als JSONL gespeichert und als CSV (wide) exportiert
    """
    api_key = os.getenv("ANTHROPIC_API_KEY")
    if not api_key:
        raise EnvironmentError("ANTHROPIC_API_KEY fehlt in env.")
    client = Anthropic(api_key=api_key)

    calls_dir = Path(calls_dir).resolve()
    guidelines_dir = Path(guidelines_dir).resolve()
    results_dir = Path(results_dir).resolve()
    results_dir.mkdir(parents=True, exist_ok=True)

    call_files = sorted(list(calls_dir.glob("*.md")) + list(calls_dir.glob("*.txt")))
    if not call_files:
        raise FileNotFoundError(f"Keine Notrufe gefunden in {calls_dir}")

    # ---- NEU: Master-Guideline laden (GENAU 1 Datei) ----
    guideline_files = sorted(list(guidelines_dir.glob("*.md")) + list(guidelines_dir.glob("*.txt")))
    if len(guideline_files) != 1:
        raise ValueError(
            f"guidelines_dir muss GENAU 1 Datei enthalten (Master Guideline). "
            f"Gefunden: {len(guideline_files)} Dateien: {[p.name for p in guideline_files]}"
        )
    master_guidelines = guideline_files[0].read_text(encoding="utf-8").strip()

    system_prompt = f"{master_guidelines}\n\n{output_contract}"

    # ---- NEU: Batch requests bauen: 1 Request pro Notruf ----
    batch_requests = []
    for fp in call_files:
        transcript = fp.read_text(encoding="utf-8").strip()
        batch_requests.append({
    "custom_id": f"{fp.stem}",
    "params": {
        "model": model,
        "temperature": float(temperature),
        "max_tokens": int(max_tokens),
        "system": system_prompt,
        "messages": [
            {"role": "user", "content": transcript}
        ],
        # --- NEU: Structured Output ---
        "output_config": {
            "format": {
                "type": "json_schema",
                "schema": ABCDE_SCHEMA,
            }
        },
    }
})

    message_batch = client.messages.batches.create(requests=batch_requests)

    # warten bis ended
    while True:
        mb = client.messages.batches.retrieve(message_batch.id)
        if mb.processing_status == "ended":
            message_batch = mb
            break
        print(f"[{message_batch.id}] processing_status={mb.processing_status} ...")
        time.sleep(poll_every_seconds)

    if not message_batch.results_url:
        raise RuntimeError(f"Batch ended, aber results_url fehlt: {message_batch}")

    # results_url downloaden (JSONL)
    headers = {
        "x-api-key": api_key,
        "anthropic-version": "2023-06-01",
    }
    r = requests.get(message_batch.results_url, headers=headers, timeout=300)
    r.raise_for_status()
    results_text = r.text

    # speichern
    out_jsonl = results_dir / f"batch_output_{message_batch.id}.jsonl"
    out_jsonl.write_text(results_text, encoding="utf-8")

    df = parse_anthropic_batch_results_jsonl_to_df(results_text)
    out_csv = next_free_run_path(results_dir, model=model, temperature=temperature)
    df.to_csv(out_csv, index=False, encoding="utf-8")

    return {
        "batch_id": message_batch.id,
        "processing_status": message_batch.processing_status,
        "results_url": message_batch.results_url,
        "output_jsonl_path": str(out_jsonl),
        "csv_path": str(out_csv),
        "df": df,
    }

# %%
from pathlib import Path

res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   
    temperature=0,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=1000,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_013WuYzWci4tivrDekeuixcP] processing_status=in_progress ...
# [msgbatch_013WuYzWci4tivrDekeuixcP] processing_status=in_progress ...
# [msgbatch_013WuYzWci4tivrDekeuixcP] processing_status=in_progress ...
# [msgbatch_013WuYzWci4tivrDekeuixcP] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_1/results/run_1_claude-sonnet-4-6_t0.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1           1           0.9
# 1  Notruf_2        2           1           0.8
# 2  Notruf_3        3           1           0.7
# 3  Notruf_4        4           1           0.7
# 4  Notruf_5        5           1           0.8
#
#                                           findings_A error_A  severity_B  \
# 0  ["Patient speaks clearly and coherently throug...    None           2
# 1  ["patient is responsive and can be spoken to",...    None           1
# 2  ["patient responds when spoken to", "no airway...    None           1
# 3  ["patient speaks in short phrases, airway appe...    None           2
# 4  ["patient is screaming, indicating open airway...    None           1
#
#    confidence_B                                         findings_B error_B  \
# 0          0.85  ["Patient reports difficulty breathing ('ich k...    None
# 1          0.90  ["caller reports father is breathing normally"...    None
# 2          0.70  ["caller explicitly states no breathing proble...    None
# 3          0.75  ["patient reports difficulty breathing ('krieg...    None
# 4          0.50  ["caller reports occasional panting ('häschelt...    None
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["Patient reports chest pain ('Brustschmerzen'...     None          1
# 1  ...  ["known history of hypertension and diabetes",...     None          2
# 2  ...  ["no chest pain or bleeding reported", "no sho...     None          2
# 3  ...  ["no dizziness reported when asked", "no chest...     None          1
# 4  ...  ["no chest pain or shock signs reported", "no ...     None          1
#
#   confidence_D                                         findings_D  error_D  \
# 0         0.85  ["Patient is oriented and communicates coheren...     None
# 1         0.90  ["slurred/garbled speech for approximately one...     None
# 2         0.70  ["patient lying on the street", "only responsi...     None
# 3         0.60  ["patient oriented to location", "answers ques...     None
# 4         0.80  ["patient is conscious and responsive", "screa...     None
#
#   severity_E confidence_E                                         findings_E  \
# 0          0          0.5  ["No trauma or external injury mentioned", "No...
# 1          1          0.5  ["no trauma or injury reported", "no environme...
# 2          1          0.6  ["patient lying on street in public area", "no...
# 3          1          0.5  ["patient located outdoors near McDonald's at ...
# 4          2          0.8  ["premature labor at 34th week of pregnancy", ...
#
#    error_E
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 22 columns]

# %%
res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   # Sonnet 4.x Modellname :contentReference[oaicite:10]{index=10}
    temperature=0.5,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=800,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_01Va7CT3D27MXYVab1W6QVqN] processing_status=in_progress ...
# [msgbatch_01Va7CT3D27MXYVab1W6QVqN] processing_status=in_progress ...
# [msgbatch_01Va7CT3D27MXYVab1W6QVqN] processing_status=in_progress ...
# [msgbatch_01Va7CT3D27MXYVab1W6QVqN] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_2/results/run_1_claude-sonnet-4-6_t0_5.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1         1.0           0.9
# 1  Notruf_2        2         1.0           0.8
# 2  Notruf_3        3         1.0           0.7
# 3  Notruf_4        4         1.0           0.7
# 4  Notruf_5        5         1.0           0.8
#
#                                           findings_A error_A  severity_B  \
# 0  ["Patient speaks clearly and coherently throug...     NaN         2.0
# 1  ["patient is responsive and can be spoken to",...     NaN         1.0
# 2  ["patient responds when spoken to", "no mentio...     NaN         1.0
# 3  ["patient speaks in short phrases, airway appe...     NaN         2.0
# 4  ["patient is screaming, indicating open airway...     NaN         2.0
#
#    confidence_B                                         findings_B error_B  \
# 0          0.85  ["Patient reports difficulty breathing ('ich k...     NaN
# 1          0.90  ["caller reports father is breathing normally"...     NaN
# 2          0.70  ["caller explicitly states no breathing proble...     NaN
# 3          0.75  ["patient reports difficulty breathing for one...     NaN
# 4          0.50  ["caller reports wife occasionally gasping/pan...     NaN
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["Patient reports chest pain ('Brustschmerzen'...      NaN        1.0
# 1  ...  ["known hypertension in medical history", "no ...      NaN        2.0
# 2  ...  ["no chest pain or bleeding reported", "no sho...      NaN        2.0
# 3  ...  ["no dizziness reported", "no chest pain menti...      NaN        1.0
# 4  ...  ["no chest pain or shock signs mentioned", "la...      NaN        1.0
#
#   confidence_D                                         findings_D  error_D  \
# 0         0.85  ["Patient is oriented and communicates coheren...      NaN
# 1         0.90  ["slurred/garbled speech for approximately one...      NaN
# 2         0.75  ["patient mostly sleeping on the street", "res...      NaN
# 3         0.60  ["patient oriented to location and age", "comm...      NaN
# 4         0.80  ["patient is conscious per calltaker confirmat...      NaN
#
#   severity_E confidence_E                                         findings_E  \
# 0        0.0          0.8  ["No trauma or external injury mentioned", "No...
# 1        0.0          0.5  ["no trauma or external injury mentioned", "no...
# 2        1.0          0.6  ["lying on the street in public", "no trauma o...
# 3        0.0          0.5  ["no trauma or injury mentioned", "patient loc...
# 4        2.0          0.8  ["premature labor at 34th week of pregnancy", ...
#
#    error_E
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 22 columns]

# %%
from pathlib import Path

res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   # Sonnet 4.x Modellname :contentReference[oaicite:10]{index=10}
    temperature=1,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=800,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_01Eq5nXxwhnsYyMdJthYKneS] processing_status=in_progress ...
# [msgbatch_01Eq5nXxwhnsYyMdJthYKneS] processing_status=in_progress ...
# [msgbatch_01Eq5nXxwhnsYyMdJthYKneS] processing_status=in_progress ...
# [msgbatch_01Eq5nXxwhnsYyMdJthYKneS] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_2/results/run_2_claude-sonnet-4-6_t1.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1           1           0.9
# 1  Notruf_2        2           1           0.8
# 2  Notruf_3        3           1           0.7
# 3  Notruf_4        4           1           0.8
# 4  Notruf_5        5           1           0.8
#
#                                           findings_A error_A  severity_B  \
# 0  ["Patient speaks clearly throughout the call",...    None           2
# 1  ["Patient is responsive and can be spoken to",...    None           1
# 2  ["patient responds when spoken to", "no airway...    None           1
# 3  ["patient speaks in short phrases but is able ...    None           2
# 4  ["Patient is screaming, indicating open airway...    None           1
#
#    confidence_B                                         findings_B error_B  \
# 0          0.85  ["Patient reports difficulty breathing (schlec...    None
# 1          0.90  ["Caller confirms father is breathing normally...    None
# 2          0.80  ["caller explicitly states no breathing proble...    None
# 3          0.80  ["patient reports difficulty breathing ('krieg...    None
# 4          0.50  ["Caller mentions patient occasionally gasps/p...    None
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["Patient reports chest pain (Brustschmerzen) ...     None          1
# 1  ...  ["Known history of hypertension and diabetes",...     None          2
# 2  ...  ["no chest pain or bleeding reported", "no sig...     None          2
# 3  ...  ["patient denies dizziness when asked", "no ch...     None          1
# 4  ...  ["No circulatory complaints mentioned", "No bl...     None          1
#
#   confidence_D                                         findings_D  error_D  \
# 0          0.8  ["Patient is oriented and communicates coheren...     None
# 1          0.9  ["Slurred/garbled speech (verwaschene Sprache)...     None
# 2          0.7  ["patient lying on the street", "mostly sleepi...     None
# 3          0.6  ["patient is conscious and responsive", "commu...     None
# 4          0.8  ["Patient is conscious and responsive", "Screa...     None
#
#   severity_E confidence_E                                         findings_E  \
# 0          0         0.50  ["No trauma or external injury mentioned", "No...
# 1          0         0.30  ["No trauma or external injury mentioned", "No...
# 2          1         0.60  ["patient found lying on street in public", "n...
# 3          1         0.50  ["patient is outside near McDonald's at Europa...
# 4          2         0.85  ["Patient is in active labor at 34 weeks gesta...
#
#    error_E
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 22 columns]

# %%
print(res)
# Out:
# {'status': 'validating', 'batch_id': 'batch_69a1a1ca68dc8190a850b245c3ede1de', 'batch_input_path': '/Users/s.franke/Development/master_clean/experiments/experiment_3/results/batch_input_abcde.jsonl', 'output_jsonl_path': None, 'csv_path': None, 'df': None}
