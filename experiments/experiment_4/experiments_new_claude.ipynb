# %%
import os
import re
import json
import time
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv
load_dotenv()
from openai import OpenAI
os.environ["ANTHROPIC_API_KEY"] = os.getenv("ANTHROPIC_API_KEY")

import os, re, json, time
from pathlib import Path

import pandas as pd
import requests
from anthropic import Anthropic

DOMAINS = ["A","B","C","D","E"]

OUTPUT_CONTRACT_DEFAULT = """
Return ONLY valid JSON (no markdown, no commentary).

Schema:
{
  "severity": <int or null>,
  "confidence": <float 0..1 or null>,
  "findings": <list of strings>
}

Rules:
- findings must be short factual phrases grounded in the call text.
- if no findings are available, return [].
- do NOT invent findings.
""".strip()


def _safe_model_name(s: str) -> str:
    return re.sub(r"[^\w\.-]+", "-", s)

def _temp_tag(t: float) -> str:
    if float(t).is_integer():
        return f"t{int(t)}"
    return f"t{str(t).replace('.', '_')}"

def next_free_run_path(results_dir: Path, model: str, temperature: float) -> Path:
    results_dir.mkdir(parents=True, exist_ok=True)
    nums = []
    for p in results_dir.glob("run_*.csv"):
        m = re.search(r"run_(\d+)_", p.name)
        if m:
            nums.append(int(m.group(1)))
    n = (max(nums) + 1) if nums else 1
    return results_dir / f"run_{n}_{_safe_model_name(model)}_{_temp_tag(temperature)}.csv"


def _extract_text_from_anthropic_message(message_obj: dict) -> str:
    # message_obj["content"] ist i.d.R. eine Liste wie [{"type":"text","text":"..."}]
    parts = []
    for c in message_obj.get("content", []) or []:
        if c.get("type") == "text" and "text" in c:
            parts.append(c["text"])
    return "\n".join(parts).strip()


def parse_anthropic_batch_results_jsonl_to_df(jsonl_text: str) -> pd.DataFrame:
    by_call = {}

    for line in jsonl_text.splitlines():
        if not line.strip():
            continue
        rec = json.loads(line)

        custom_id = rec.get("custom_id")  # Notruf_12__A
        if not custom_id or "__" not in custom_id:
            continue
        call_id, domain = custom_id.split("__", 1)
        domain = domain.upper()
        if domain not in DOMAINS:
            continue

        by_call.setdefault(call_id, {"file": call_id})

        result = rec.get("result") or {}
        rtype = result.get("type")

        if rtype != "succeeded":
            # errored / canceled / expired
            by_call[call_id][f"severity_{domain}"] = None
            by_call[call_id][f"confidence_{domain}"] = None
            by_call[call_id][f"findings_{domain}"] = json.dumps([], ensure_ascii=False)
            by_call[call_id][f"error_{domain}"] = json.dumps(result, ensure_ascii=False)
            continue

        msg = result.get("message") or {}
        text = _extract_text_from_anthropic_message(msg)

        # JSON aus Text extrahieren (dein Contract fordert reines JSON, aber wir sind robust)
        m = re.search(r"\{.*\}", text, flags=re.S)
        if not m:
            by_call[call_id][f"severity_{domain}"] = None
            by_call[call_id][f"confidence_{domain}"] = None
            by_call[call_id][f"findings_{domain}"] = json.dumps([], ensure_ascii=False)
            by_call[call_id][f"error_{domain}"] = f"parse_error: no_json_in_text: {text[:200]}"
            continue

        try:
            data = json.loads(m.group(0))
            sev = data.get("severity")
            conf = data.get("confidence")
            findings = data.get("findings", [])
            if findings is None:
                findings = []
            if not isinstance(findings, list):
                findings = [str(findings)]
        except Exception as e:
            by_call[call_id][f"severity_{domain}"] = None
            by_call[call_id][f"confidence_{domain}"] = None
            by_call[call_id][f"findings_{domain}"] = json.dumps([], ensure_ascii=False)
            by_call[call_id][f"error_{domain}"] = f"parse_error: {e}"
            continue

        by_call[call_id][f"severity_{domain}"] = sev
        by_call[call_id][f"confidence_{domain}"] = conf
        by_call[call_id][f"findings_{domain}"] = json.dumps(findings, ensure_ascii=False)
        by_call[call_id][f"error_{domain}"] = None

    df = pd.DataFrame(list(by_call.values()))
    df["call_nr"] = df["file"].str.extract(r"(\d+)").astype("Int64")
    df = df.sort_values(["call_nr", "file"], na_position="last").reset_index(drop=True)

    cols = ["file", "call_nr"]
    for d in DOMAINS:
        cols += [f"severity_{d}", f"confidence_{d}", f"findings_{d}", f"error_{d}"]
    for c in cols:
        if c not in df.columns:
            df[c] = None
    return df[cols]


def run_abcde_batch_experiment_anthropic(
    model: str,
    temperature: float,
    *,
    calls_dir: Path,
    guidelines_dir: Path,
    results_dir: Path,
    max_tokens: int = 400,
    poll_every_seconds: int = 30,
):
    """
    Claude Message Batches:
    - create batch with inline requests
    - poll processing_status until 'ended'
    - download results from results_url (JSONL)
    - parse to DF + save CSV as run_N_<model>_tX.csv
    """
    api_key = os.getenv("ANTHROPIC_API_KEY")
    if not api_key:
        raise EnvironmentError("ANTHROPIC_API_KEY fehlt in env.")
    client = Anthropic(api_key=api_key)

    calls_dir = Path(calls_dir).resolve()
    guidelines_dir = Path(guidelines_dir).resolve()
    results_dir = Path(results_dir).resolve()
    results_dir.mkdir(parents=True, exist_ok=True)

    call_files = sorted(list(calls_dir.glob("*.md")) + list(calls_dir.glob("*.txt")))
    if not call_files:
        raise FileNotFoundError(f"Keine Notrufe gefunden in {calls_dir}")

    # guidelines laden
    domain_guidelines = {}
    for d in DOMAINS:
        p = guidelines_dir / f"{d.lower()}_guidelines.md"
        if not p.exists():
            raise FileNotFoundError(f"Guideline fehlt: {p}")
        domain_guidelines[d] = p.read_text(encoding="utf-8").strip()

    # Batch requests bauen (inline) :contentReference[oaicite:7]{index=7}
    batch_requests = []
    for fp in call_files:
        transcript = fp.read_text(encoding="utf-8").strip()
        for domain in DOMAINS:
            batch_requests.append({
                "custom_id": f"{fp.stem}__{domain}",
                "params": {
                    "model": model,
                    "temperature": temperature,
                    "max_tokens": max_tokens,
                    "system": f"{domain_guidelines[domain]}\n\n{OUTPUT_CONTRACT_DEFAULT}",
                    "messages": [
                        {"role": "user", "content": transcript}
                    ],
                }
            })

    message_batch = client.messages.batches.create(requests=batch_requests)

    # warten bis ended :contentReference[oaicite:8]{index=8}
    while True:
        mb = client.messages.batches.retrieve(message_batch.id)
        if mb.processing_status == "ended":
            message_batch = mb
            break
        print(f"[{message_batch.id}] processing_status={mb.processing_status} ...")
        time.sleep(poll_every_seconds)

    if not message_batch.results_url:
        raise RuntimeError(f"Batch ended, aber results_url fehlt: {message_batch}")

    # results_url downloaden (JSONL) :contentReference[oaicite:9]{index=9}
    headers = {
        "x-api-key": api_key,
        "anthropic-version": "2023-06-01",
    }
    r = requests.get(message_batch.results_url, headers=headers, timeout=300)
    r.raise_for_status()
    results_text = r.text

    # speichern
    out_jsonl = results_dir / f"batch_output_{message_batch.id}.jsonl"
    out_jsonl.write_text(results_text, encoding="utf-8")

    df = parse_anthropic_batch_results_jsonl_to_df(results_text)
    out_csv = next_free_run_path(results_dir, model=model, temperature=temperature)
    df.to_csv(out_csv, index=False, encoding="utf-8")

    return {
        "batch_id": message_batch.id,
        "processing_status": message_batch.processing_status,
        "results_url": message_batch.results_url,
        "output_jsonl_path": str(out_jsonl),
        "csv_path": str(out_csv),
        "df": df,
    }

# %%
from pathlib import Path

res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   # Sonnet 4.x Modellname :contentReference[oaicite:10]{index=10}
    temperature=0,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=400,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# [msgbatch_01Sq4vuT6TaayUYxFHKymSGi] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_2/results/run_1_claude-sonnet-4-6_t0.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1           2          0.60
# 1  Notruf_2        2           2          0.72
# 2  Notruf_3        3           2          0.45
# 3  Notruf_4        4           2          0.55
# 4  Notruf_5        5           1          0.60
#
#                                           findings_A error_A  severity_B  \
# 0  ["caller reports difficulty breathing ('ich kr...    None           2
# 1  ["patient has slurred/garbled speech for appro...    None           1
# 2  ["patient is responsive when addressed but oth...    None           1
# 3  ["caller reports difficulty breathing ('krieg ...    None           2
# 4  ["patient is screaming, indicating ability to ...    None           1
#
#    confidence_B                                         findings_B error_B  \
# 0          0.75  ["caller reports difficulty breathing (schlech...    None
# 1          0.85  ["caller explicitly states father is breathing...    None
# 2          0.60  ["caller explicitly denies breathing problems ...    None
# 3          0.60  ["caller reports difficulty breathing ('kriegt...    None
# 4          0.60  ["caller reports wife occasionally gasping sli...    None
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["chest pain reported, onset a few minutes ago...     None          1
# 1  ...  ["no bleeding mentioned", "no collapse reporte...     None          2
# 2  ...  ["patient lying on the street", "responsive wh...     None          2
# 3  ...  ["caller denies dizziness when asked about cir...     None          1
# 4  ...                                                 []     None          1
#
#   confidence_D                                         findings_D  error_D  \
# 0         0.60  ["caller is self-reporting and communicating c...     None
# 1         0.82  ["slurred speech present for approximately one...     None
# 2         0.65  ["patient responsive when spoken to but otherw...     None
# 3         0.55  ["caller is awake and able to communicate", "c...     None
# 4         0.80  ["patient is conscious", "patient is responsiv...     None
#
#   severity_E confidence_E                                         findings_E  \
# 0          1          0.7  ["no trauma mechanism reported", "no environme...
# 1          1          0.8  ["no trauma mechanism reported", "no visible i...
# 2          1          0.6  ["man found lying on the street in public", "n...
# 3          0          0.9  ["no trauma mechanism reported", "no visible i...
# 4          1          0.7  ["premature labor at 34 weeks gestation", "pat...
#
#    error_E
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 22 columns]

# %%
from pathlib import Path

res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   # Sonnet 4.x Modellname :contentReference[oaicite:10]{index=10}
    temperature=0.5,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=400,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# [msgbatch_017swbuvgnFX9AfXF6TAG3Tf] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_2/results/run_2_claude-sonnet-4-6_t0_5.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1           2          0.65
# 1  Notruf_2        2           2          0.60
# 2  Notruf_3        3           2          0.45
# 3  Notruf_4        4           2          0.55
# 4  Notruf_5        5           1          0.60
#
#                                           findings_A error_A  severity_B  \
# 0  ["caller reports difficulty breathing ('ich kr...    None           2
# 1  ["patient has slurred/garbled speech ('verwasc...    None           1
# 2  ["patient is drowsy/sleeping and only responsi...    None           1
# 3  ["caller reports difficulty breathing ('krieg ...    None           2
# 4  ["patient is screaming, indicating ability to ...    None           2
#
#    confidence_B                                         findings_B error_B  \
# 0          0.72  ["caller reports difficulty breathing ('ich kr...    None
# 1          0.85  ["caller explicitly states father is breathing...    None
# 2          0.60  ["caller explicitly denied breathing problems ...    None
# 3          0.60  ["caller reports difficulty breathing ('kriegt...    None
# 4          0.40  ["caller reports wife occasionally gasping ('h...    None
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["chest pain reported, onset a few minutes ago...     None          1
# 1  ...  ["no bleeding mentioned", "no collapse reporte...     None          2
# 2  ...  ["patient found lying on the street", "respond...     None          2
# 3  ...  ["no dizziness reported", "no pain reported", ...     None          1
# 4  ...                                                 []     None          1
#
#   confidence_D                                         findings_D  error_D  \
# 0         0.60  ["caller is self-reporting and communicating c...     None
# 1         0.82  ["slurred speech present for approximately one...     None
# 2         0.70  ["patient responds when spoken to but otherwis...     None
# 3         0.55  ["caller is awake and able to communicate thro...     None
# 4         0.70  ["patient is conscious", "patient is screaming...     None
#
#   severity_E confidence_E                                         findings_E  \
# 0          1          0.7  ["no trauma mechanism reported", "no environme...
# 1          1          0.8  ["no trauma mechanism reported", "no visible i...
# 2          1          0.6  ["man found lying on street in public area", "...
# 3          0          0.9  ["no trauma mechanism reported", "no visible i...
# 4          1          0.7  ["premature labor at 34 weeks gestation in a h...
#
#    error_E
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 22 columns]

# %%
from pathlib import Path

res = run_abcde_batch_experiment_anthropic(
    model="claude-sonnet-4-6",   # Sonnet 4.x Modellname :contentReference[oaicite:10]{index=10}
    temperature=1,
    calls_dir=Path("../../emergency_calls/calls_german"),
    guidelines_dir=Path("guidelines"),
    results_dir=Path("results"),
    max_tokens=400,
)

print(res["csv_path"])
res["df"].head()
# Out:
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# [msgbatch_01MY2WyhFfFMpXXBwDKmpakw] processing_status=in_progress ...
# /Users/s.franke/Development/master_clean/experiments/experiment_2/results/run_3_claude-sonnet-4-6_t1.csv
#        file  call_nr  severity_A  confidence_A  \
# 0  Notruf_1        1           2          0.60
# 1  Notruf_2        2           2          0.72
# 2  Notruf_3        3           2          0.45
# 3  Notruf_4        4           2          0.55
# 4  Notruf_5        5           1          0.60
#
#                                           findings_A error_A  severity_B  \
# 0  ["caller reports difficulty breathing ('ich kr...    None           2
# 1  ["patient has slurred/garbled speech (verwasch...    None           1
# 2  ["patient is minimally responsive, only reacts...    None           1
# 3  ["caller reports difficulty breathing ('krieg ...    None           2
# 4  ["patient is screaming, indicating ability to ...    None           1
#
#    confidence_B                                         findings_B error_B  \
# 0          0.75  ["caller reports difficulty breathing (schlech...    None
# 1          0.85  ["caller explicitly states father is breathing...    None
# 2          0.60  ["caller explicitly denied breathing problems ...    None
# 3          0.60  ["caller reports difficulty breathing ('krieg ...    None
# 4          0.55  ["caller reports wife occasionally breathing f...    None
#
#    ...                                         findings_C  error_C severity_D  \
# 0  ...  ["chest pain reported, onset a few minutes ago...     None          1
# 1  ...                                                 []     None          2
# 2  ...  ["patient found lying on street", "responsive ...     None          2
# 3  ...  ["caller denies dizziness when asked", "caller...     None          1
# 4  ...  ["no bleeding mentioned", "patient is consciou...     None          1
#
#   confidence_D                                         findings_D  error_D  \
# 0         0.60  ["caller is self-reporting and communicating c...     None
# 1         0.82  ["slurred speech present for approximately one...     None
# 2         0.65  ["patient is lying on the street", "responds w...     None
# 3         0.55  ["caller is conscious and able to communicate ...     None
# 4         0.70  ["patient is conscious as confirmed by calltak...     None
#
#   severity_E confidence_E                                         findings_E  \
# 0          1          0.7  ["no trauma mechanism reported", "no environme...
# 1          1          0.8  ["no trauma mechanism reported", "no visible i...
# 2          1          0.6  ["man found lying on the street in public", "n...
# 3          0          0.9  ["no trauma mechanism mentioned", "no visible ...
# 4          1          0.7  ["premature labor at 34 weeks gestation (no tr...
#
#    error_E
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#
# [5 rows x 22 columns]

# %%
print(res)
# Out:
# {'status': 'validating', 'batch_id': 'batch_69a1a1ca68dc8190a850b245c3ede1de', 'batch_input_path': '/Users/s.franke/Development/master_clean/experiments/experiment_3/results/batch_input_abcde.jsonl', 'output_jsonl_path': None, 'csv_path': None, 'df': None}
